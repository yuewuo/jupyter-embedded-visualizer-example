# %% [markdown]
# # Jupyter Display Test

# %% [markdown]
# ## Requirement

# %% [markdown]
# We need to display a few information for faster debugging, including
# - display the decoding hypergraph
# - display the parity matrix
#
# Both of them are self-contained: meaning no interactive information is needed between the Python program and the display frontend.
# They do need some interaction from the user, for example, rotating the view angle of a 3D decoding hypergraph.
#
# In order to fit this need, the best solution is to embed a piece of HTML inside the jupyter notebook.
# We can potentially run Javascripts in the HTML block to enable interaction between the user and the view.

# %%
import hyperion_visual
hyperion_visual.display_test_matrix()
# Out:
# <script type="module" id='hyperion_visual_compressed_js_caller'>
#                            /* HYPERION_VISUAL_MODULE_CODE_BEGIN */
#
# const module_base64 = "..."
# // console.log(module_base64)
# function uint8_to_array_buffer(array) {
#     return array.buffer.slice(array.byteOffset, array.byteLength + array.byteOffset)
# }
# function base64_to_array_buffer(base64_str) {
#     return uint8_to_array_buffer(Uint8Array.from(atob(base64_str), c => c.charCodeAt(0)))
# }
# async function decompress_content(base64_str) {
#     const base64_binary = base64_to_array_buffer(base64_str)
#     const blob = new Blob([base64_binary])
#     const decompressed_stream = blob.stream()
#         .pipeThrough(new DecompressionStream('gzip'))
#     const decompressed = await new Response(decompressed_stream).arrayBuffer()
#     return decompressed
# }
# async function load_module() {
#     const decompressed = await decompress_content(module_base64)
# ...

# %%
hyperion_visual.display_test_hypergraph()
# Out:
# <div style="width: 50%;" id="pojmjdrwgnqywulx"></div>
